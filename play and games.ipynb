# %%
import pandas as pd

# %%
data = pd.read_csv('https://raw.githubusercontent.com/rminkah/STAT222/master/GHApparel.csv')

# %%
data
# Out:
#      Customer Type of Customer  Items  Net Sales Method of Payment  Gender  \
# 0           1          Regular     10     129.10        MasterCard    Male
# 1           2      Promotional      1     275.47              Visa  Female
# 2           3      Promotional      3     104.35              Visa    Male
# 3           4          Regular      1     205.54        MasterCard  Female
# 4           5      Promotional      6     292.64        MasterCard    Male
# ..        ...              ...    ...        ...               ...     ...
# 495       496      Promotional      7     211.21        MasterCard  Female
# 496       497          Regular      2     149.35  Proprietary Card    Male
# 497       498      Promotional      4     198.25        MasterCard  Female
# 498       499          Regular      8     123.56          Discover    Male
# 499       500      Promotional      5     114.73          Discover  Female
#
#     Marital Status  Age  Unnamed: 8
# ...

# %%
import os

notebook_path = os.getcwd()
print(notebook_path)
# Out:
# C:\Users\ASUS\project
