# %%
import pandas as pd
import torch
import torch.nn as nn
import torch.optim as optim
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from torch.utils.data import DataLoader, TensorDataset
import torch.optim as optim

# %%
# Read the CSV file into a DataFrame
data = pd.read_csv('raw_btcusd.csv')

# Create new columns for high and low target by shifting 'high' and 'low' by -1
data['hightarget'] = data['high'].shift(-1)
data['lowtarget'] = data['low'].shift(-1)

# Drop rows containing NaN values
data.dropna(inplace=True)

# Check for NaN values in the DataFrame
print(data.isna().sum())
# Out:
# time           0
# open           0
# high           0
# low            0
# close          0
# tick_volume    0
# hightarget     0
# lowtarget      0
# dtype: int64

# %%
# Separate features and targets
X = data[['open', 'high', 'low', 'close', 'tick_volume']]
y = data[['hightarget', 'lowtarget']]

# Normalize the data
scaler_x = StandardScaler()
scaler_y = StandardScaler()

X_scaled = scaler_x.fit_transform(X)
y_scaled = scaler_y.fit_transform(y)

# Split into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled, test_size=0.2, random_state=42)

# Convert to PyTorch tensors
X_train_tensor = torch.tensor(X_train, dtype=torch.float32)
y_train_tensor = torch.tensor(y_train, dtype=torch.float32)
X_test_tensor = torch.tensor(X_test, dtype=torch.float32)
y_test_tensor = torch.tensor(y_test, dtype=torch.float32)

# %%
train_dataset = TensorDataset(X_train_tensor, y_train_tensor)
train_loader = DataLoader(train_dataset, batch_size=16, shuffle=True)

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        self.fc1 = nn.Linear(5, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 2)

    def forward(self, x):
        x = torch.relu(self.fc1(x))
        x = torch.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# Initialize the model, loss function, and optimizer
model = Net()
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)

# %%
import matplotlib.pyplot as plt

# Initialize a list to store loss values
loss_values = []

# Training the model
epochs = 50
for epoch in range(epochs):
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()

    # Store the loss value for this epoch
    loss_values.append(loss.item())

    # Print loss up to 6 decimal places
    print(f"Epoch {epoch+1}/{epochs} => Loss: {loss.item():.6f}")

# Plotting
plt.figure(figsize=(10, 6))
plt.plot(range(1, epochs+1), loss_values)
plt.title('Learning Curve')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.grid(True)
plt.show()
# Out:
# Epoch 1/50 => Loss: 0.000140
# Epoch 2/50 => Loss: 0.001773
# Epoch 3/50 => Loss: 0.000171
# Epoch 4/50 => Loss: 0.000288
# Epoch 5/50 => Loss: 0.001612
# Epoch 6/50 => Loss: 0.000093
# Epoch 7/50 => Loss: 0.000201
# Epoch 8/50 => Loss: 0.000364
# Epoch 9/50 => Loss: 0.000059
# Epoch 10/50 => Loss: 0.000168
# Epoch 11/50 => Loss: 0.000322
# Epoch 12/50 => Loss: 0.000067
# Epoch 13/50 => Loss: 0.000136
# Epoch 14/50 => Loss: 0.000093
# Epoch 15/50 => Loss: 0.000049
# Epoch 16/50 => Loss: 0.000155
# Epoch 17/50 => Loss: 0.000456
# Epoch 18/50 => Loss: 0.000039
# Epoch 19/50 => Loss: 0.000186
# Epoch 20/50 => Loss: 0.000197
# Epoch 21/50 => Loss: 0.000052
# Epoch 22/50 => Loss: 0.000088
# Epoch 23/50 => Loss: 0.000016
# Epoch 24/50 => Loss: 0.000042
# Epoch 25/50 => Loss: 0.000140
# Epoch 26/50 => Loss: 0.000336
# Epoch 27/50 => Loss: 0.000054
# Epoch 28/50 => Loss: 0.000110
# Epoch 29/50 => Loss: 0.000080
# Epoch 30/50 => Loss: 0.000119
# Epoch 31/50 => Loss: 0.000081
# ...

# %%
# Evaluation
model.eval()
with torch.no_grad():
    y_pred_tensor = model(X_test_tensor)
    loss = criterion(y_pred_tensor, y_test_tensor)
print(f"Test Loss: {loss.item()}")
# Out:
# Test Loss: 0.0001537752104923129

# %%
# Assuming new_data is your new DataFrame containing ['open', 'high', 'low', 'close', 'tick_volume']
new_data_scaled = scaler_x.transform(X.tail(30))
new_data_tensor = torch.tensor(new_data_scaled, dtype=torch.float32)

model.eval()
with torch.no_grad():
    future_pred_scaled = model(new_data_tensor).numpy()

# Inverse transform to get original values
future_pred = scaler_y.inverse_transform(future_pred_scaled)
print("Future high target:", future_pred[0][0])
print("Future low target:", future_pred[0][1])
# Out:
# Future high target: 30448.006
# Future low target: 30117.238

# %%
X
# Out:
#             open       high        low      close  tick_volume
# 0       1041.319   1041.320   1041.220   1041.222           68
# 1       1041.222   1042.778   1041.220   1042.000          185
# 2       1043.000   1043.000   1042.007   1042.007           32
# 3       1042.989   1042.989   1042.000   1042.003           50
# 4       1043.000   1043.000   1041.504   1042.007          162
# ...          ...        ...        ...        ...          ...
# 53636  30195.538  30311.738  30191.338  30244.238         1352
# 53637  30244.238  30268.338  30222.973  30239.538          641
# 53638  30239.538  30239.538  30170.238  30187.838          738
# 53639  30187.838  30187.838  30025.638  30098.838         1713
# 53640  30098.838  30148.138  30039.738  30138.838         1429
#
# [53641 rows x 5 columns]

# %%
# Save the model
torch.save(model.state_dict(), 'high_and_lows.pth')

# %%
# Initialize the model architecture
model = Net()

# Load the saved state dictionary into the model
model.load_state_dict(torch.load('high_and_lows.pth'))

# Set the model to evaluation mode
model.eval()
# Out:
# Net(
#   (fc1): Linear(in_features=5, out_features=64, bias=True)
#   (fc2): Linear(in_features=64, out_features=32, bias=True)
#   (fc3): Linear(in_features=32, out_features=2, bias=True)
# )

# %%
def get_HnL_Predictions(data):
    new_data_scaled = scaler_x.transform(data.tail(30))
    new_data_tensor = torch.tensor(new_data_scaled, dtype=torch.float32)

    # Initialize the model architecture
    model = Net()

    # Load the saved state dictionary into the model
    model.load_state_dict(torch.load('high_and_lows.pth'))

    model.eval()
    with torch.no_grad():
        future_pred_scaled = model(new_data_tensor).numpy()

    # Inverse transform to get original values
    new_hnl_prediction = scaler_y.inverse_transform(future_pred_scaled)
    
    return new_hnl_prediction

# %%
data=pd.read_csv('raw_btcusd.csv').drop('time', axis =1)
new =get_HnL_Predictions(data)

# %%
new
# Out:
# array([[26167.129, 25881.809],
#        [26149.19 , 25864.062],
#        [26158.709, 25873.48 ],
#        [26173.588, 25888.201],
#        [26103.25 , 25818.611],
#        [26116.465, 25831.684],
#        [26107.98 , 25823.29 ],
#        [26086.533, 25802.07 ],
#        [26097.662, 25813.08 ],
#        [26042.703, 25758.705],
#        [26029.527, 25745.67 ],
#        [26002.715, 25719.14 ],
#        [26046.154, 25762.12 ],
#        [25994.545, 25711.059],
#        [26018.906, 25735.16 ],
#        [26070.244, 25785.953],
#        [26259.7  , 25973.398],
#        [26194.236, 25908.63 ],
#        [26223.664, 25937.744],
#        [26190.412, 25904.848],
#        [26230.31 , 25944.32 ],
#        [26236.068, 25950.018],
#        [26227.84 , 25941.877],
#        [26085.738, 25801.285],
#        [26075.785, 25791.436],
#        [26059.867, 25775.69 ],
#        [26136.26 , 25851.27 ],
#        [26210.447, 25924.666],
#        [26226.871, 25940.918],
# ...
